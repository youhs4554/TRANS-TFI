# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os, sys
sys.path.append(os.path.abspath('..'))

# %%
from btdsa.config import Config, BASELINE_MODEL_FAMILY, TDSA_MODEL_LIST
from btdsa.eval_utils import EvalSurv
from btdsa.train_utils import init_trainer
from btdsa.utils import create_logger

# %%
logger = create_logger(logs_dir='./logs')

# %%
def run_experiment(model_name, time_range='full'):
    ev = EvalSurv()  # custom evaluation interface

    cfg = Config
    cfg.model_name = model_name
    cfg.time_range = time_range
    cfg.random_state = 1234 # will be repeated across multiple random_state variables
    cfg.setup()

    for dataset in cfg.list_of_datasets:
        trainer = init_trainer(cfg)
        trainer.logger = logger # assign logger
        
        surv, model = trainer.fit_and_predict(dataset)
        ev.trainer = trainer
        x_test, y_test = trainer.test
        ev.evaluate(surv, x_test, y_test)
    ev.report()  # log and report results in beautiful tables
    
def run_all_exp(model_list, time_range):
    for model_name in model_list:
        run_experiment(model_name, time_range=time_range)

# %% [markdown]
# ## Models

# %%
simpler_ver = True # set False, for faster experiments

if simpler_ver:
    MODEL_LIST = ['CoxPH', 'DeepHitSingle', 'DRSA', 'BTDSA']
else:
    MODEL_LIST = BASELINE_MODEL_FAMILY + TDSA_MODEL_LIST

# %% [markdown]
# ## time_range = `full`

# %%
run_all_exp(MODEL_LIST, 'full')
# Out:
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                                                       CoxPH                                                                                       |
# +-----------------------------------------------------------+-----------------------------------------------------------+-----------------------------------------------------------+
# |                            gbsg                           |                          metabric                         |                          support                          |
# +-----------------------------------------------------------+-----------------------------------------------------------+-----------------------------------------------------------+
# |                0.641857 (0.638766,0.644949)               |                0.676998 (0.673932,0.680064)               |                0.603445 (0.602009,0.604881)               |
# | [25.0%] C-td: 0.714548, Brier: 0.111738, AUC-td: 0.726683 | [25.0%] C-td: 0.707726, Brier: 0.111212, AUC-td: 0.720224 | [25.0%] C-td: 0.578920, Brier: 0.142824, AUC-td: 0.585448 |
# | [50.0%] C-td: 0.661400, Brier: 0.192754, AUC-td: 0.676015 | [50.0%] C-td: 0.699774, Brier: 0.177748, AUC-td: 0.729537 | [50.0%] C-td: 0.582946, Brier: 0.220514, AUC-td: 0.600183 |
# | [75.0%] C-td: 0.647487, Brier: 0.229621, AUC-td: 0.671605 | [75.0%] C-td: 0.679437, Brier: 0.219339, AUC-td: 0.720236 | [75.0%] C-td: 0.598437, Brier: 0.234936, AUC-td: 0.648141 |
# |                                                           |                                                           |                                                           |
# +-----------------------------------------------------------+-----------------------------------------------------------+-----------------------------------------------------------+
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                                             DeepHitSingle(full, L=20)                                                                             |
# +-----------------------------------------------------------+-----------------------------------------------------------+-----------------------------------------------------------+
# |                            gbsg                           |                          metabric                         |                          support                          |
# +-----------------------------------------------------------+-----------------------------------------------------------+-----------------------------------------------------------+
# |                0.541706 (0.538434,0.544979)               |                0.675441 (0.672447,0.678435)               |                0.608999 (0.607445,0.610553)               |
# | [25.0%] C-td: 0.533970, Brier: 0.123253, AUC-td: 0.533119 | [25.0%] C-td: 0.725464, Brier: 0.113570, AUC-td: 0.739835 | [25.0%] C-td: 0.638106, Brier: 0.160664, AUC-td: 0.645318 |
# | [50.0%] C-td: 0.561266, Brier: 0.207801, AUC-td: 0.565770 | [50.0%] C-td: 0.682814, Brier: 0.192364, AUC-td: 0.704892 | [50.0%] C-td: 0.617117, Brier: 0.253626, AUC-td: 0.636344 |
# | [75.0%] C-td: 0.605741, Brier: 0.245995, AUC-td: 0.619543 | [75.0%] C-td: 0.613048, Brier: 0.239326, AUC-td: 0.655072 | [75.0%] C-td: 0.591571, Brier: 0.252352, AUC-td: 0.649219 |
# |                                                           |                                                           |                                                           |
# +-----------------------------------------------------------+-----------------------------------------------------------+-----------------------------------------------------------+
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                                